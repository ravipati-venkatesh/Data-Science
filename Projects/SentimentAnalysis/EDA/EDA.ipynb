# %%
import pandas as pd
import os
import re
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA ON IMDB ratings dataset

# %%
data_df = pd.read_csv("./../Data/Raw/IMDB Dataset sample.csv")

# %%
data_df.shape
# Out:
# (1999, 2)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     1999 non-null   object
#  1   sentiment  1999 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
sum([len(i) for i in data_df['review'].values])/len([len(i) for i in data_df['review'].values])
# Out:
# 1282.3861930965484

# %% [markdown]
# # Check if the data is imbalanced or not

# %%
data_df['sentiment'].value_counts()
# Out:
# sentiment
# negative    2532
# positive    2468
# Name: count, dtype: int64

# %%
data_df['review'].unique()
# Out:
# array(["One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due 
# ...

# %%
data_df['review'] = data_df['review'].apply(lambda x: re.sub(r'<br /><br />', '', x))
data_df['review'] = data_df['review'].apply(lambda x: re.sub(r'\'', '', x))

# %%
data_df['review'].unique()
# Out:
# array(['One of the other reviewers has mentioned that after watching just 1 Oz episode youll be hooked. They are right, as this is exactly what happened with me.The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.I would say the main appeal of the show is due to the fact that it goes where other 
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# # wordcloud

# %%
text = " ".join(data_df['review'].unique())

# %%
plt.figure(figsize=(15,7))
cloud = WordCloud(height=800, width=1600)
cloud_ = cloud.generate(text)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Frequency plot

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Tokenize the text into words
words = text.split()

# Get the frequency distribution
word_freq = Counter(words)

# Plot the frequency distribution
plt.figure(figsize=(10, 5))
plt.bar(word_freq.keys(), word_freq.values())
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Word Frequency Distribution')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\ravip\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 151 (\x97) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ravip\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ravip\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 132 (\x84) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# ...
